# %% [markdown]
# <a href="https://colab.research.google.com/github/fernanda993/hello-word/blob/master/Machine_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
url = 'https://raw.githubusercontent.com/cassiasamp/jul-20-calculadora-imoveis/master/coleta_de_dados/dados_mercado_livre.csv'

# %%
dfml = pd.read_csv(url)

# %%
dfml.describe()
# Out:
#               precos      quartos        areas
# count    1152.000000  1103.000000  1149.000000
# mean    58433.302083     2.135086   127.228895
# std    208259.538044     0.895072   354.052988
# min      1000.000000     1.000000     6.000000
# 25%      1600.000000     1.000000    50.000000
# 50%      2420.000000     2.000000    70.000000
# 75%      4197.000000     3.000000   108.000000
# max    999000.000000     6.000000  7800.000000

# %%
dfml.describe().T
# Out:
#           count          mean            std  ...     50%     75%       max
# precos   1152.0  58433.302083  208259.538044  ...  2420.0  4197.0  999000.0
# quartos  1103.0      2.135086       0.895072  ...     2.0     3.0       6.0
# areas    1149.0    127.228895     354.052988  ...    70.0   108.0    7800.0
#
# [3 rows x 8 columns]

# %%
plt.scatter(dfml['quartos'],dfml['precos'])

# %%
plt.bar(dfml['zona'],dfml['precos'])
plt.title('Meu Grafico')
plt.show()

# %%
sns.distplot(dfml['precos'])

# %%
sns.boxplot(dfml['zona'],dfml['precos'])

# %%
sns.distplot(dfml['areas']);

# %%
dfml.describe().T
# Out:
#           count          mean            std  ...     50%     75%       max
# precos   1152.0  58433.302083  208259.538044  ...  2420.0  4197.0  999000.0
# quartos  1103.0      2.135086       0.895072  ...     2.0     3.0       6.0
# areas    1149.0    127.228895     354.052988  ...    70.0   108.0    7800.0
#
# [3 rows x 8 columns]

# %%
filtro_areas = dfml['areas'] < 108

# %%
sns.pairplot(dfml)

# %%
sns.pairplot(dfml, hue = 'zona')
